# %% [markdown]
# <a href="https://colab.research.google.com/github/DIEGO-LEONEL-BARRON-SIMENTAL-ITD-hub/Probabilidad-y-Estad-stica/blob/main/UNIDAD3/Practica_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadística
# ## Unidad 3
# ### Facilitador: José Gabriel Rodriguez Rivas
# ### Alumno: Diego Leonel Barrón Simental
# ### **Practica 5**

# %%
# -----------------------------------------------------
# Gráfica de una distribución de probabilidad discreta
# con media, varianza y desviación estándar
# -----------------------------------------------------

import matplotlib.pyplot as plt
import numpy as np

# Datos: valores de la variable aleatoria y sus probabilidades
x= np.array([5,6,7,8,9,10])
p= np.array([0.05,0.10,0.20,0.30,0.25,0.10])

#Calculo del valor esperado (media)
esperanza = np.sum(x*p)

# Calculo de la esperanza del cuadrado
esperanza_cuadrado = np.sum(x**2 * p)

# Calculo de la varianza y desviación estándar
varianza = esperanza_cuadrado - esperanza **2
desviacion = np.sqrt(varianza)

# Mostrar los resultados en consola
print(f"E(X) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviación Estándar = {desviacion:.2f}")

# Crear la gráfica 'stem' (tallos y hojas)
plt.stem(x, p, basefmt=" ", linefmt='b-',markerfmt='bo')
plt.title("Distribución de la probabilidad Discreta\ncon Media y Desviación Estándar")
plt.xlabel("Valores de la variable aleatoria X")
plt.ylabel("P(X)")
plt.grid(True, linestyle='--', alpha=0.6)

# Dibujar línea vertical en la media
plt.axvline(x=esperanza, color='red', linestyle='--', label=f"Media (E(X)) = {esperanza:.2f}")

# Resaltar el rango de ±1 desviación estándar
plt.axvspan(esperanza-desviacion, esperanza+desviacion, color='red',alpha=0.2,label=f"±1 Desv. Estándar (σ = {desviacion:.2f})")

# Mostrar leyenday límites
plt.legend()
plt.ylim(0, max(p) + 0.05)
plt.xticks(x)

# Mostrar la gráfica
plt.show()
# Out:
# E(X) = 7.90
# E(X^2) = 64.10
# Varianza = 1.69
# Desviación Estándar = 1.30
