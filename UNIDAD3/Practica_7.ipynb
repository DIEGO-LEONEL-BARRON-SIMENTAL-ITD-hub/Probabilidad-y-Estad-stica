# %% [markdown]
# <a href="https://colab.research.google.com/github/DIEGO-LEONEL-BARRON-SIMENTAL-ITD-hub/Probabilidad-y-Estad-stica/blob/main/UNIDAD3/Practica_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadística
# ## Unidad 3
# ### Facilitador: José Gabriel Rodriguez Rivas
# ### Alumno: Diego Leonel Barrón Simental
# ### **Practica 7: Ejercicio 2**

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
# Variable aleatoria y sus probabilidades
x= np.array([0,10,20,50])
p= np.array([0.50,0.30,0.15,0.05])

print(f"La suma de las probabilidades es: {p.sum()}")

# Valor esperado
esperanza = np.sum(x*p)

#Esperanza al cuadrado
esperanza_cuadrado = np.sum(x**2 *p)

# Varianza y desviación estándar
varianza = esperanza_cuadrado - esperanza **2
desviacion = np.sqrt(varianza)

# Mostrar los resultados en consola
print(f"E(X) = {esperanza:.2f}")
print(f"E(X²) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviación Estándar = {desviacion:.2f}")

# Crear la gráfica 'stem' (tallos y hojas)
plt.stem(x, p, basefmt=" ", linefmt='b-',markerfmt='bo')
plt.title("Distribución de la probabilidad Discreta\ncon Media y Desviación Estándar")
plt.xlabel("Gananacia obtenida por boleto")
plt.ylabel("P(X)")
plt.grid(True, linestyle='--', alpha=0.6)

# Linea de la media
plt.axvline(x=esperanza, color='red', linestyle='--', label=f"Media (E(X)) = {esperanza:.2f}")

# Rango de ±1 desviación estándar
plt.axvspan(esperanza-desviacion, esperanza+desviacion, color='red',alpha=0.2,label=f"±1 Desv. Estándar (σ = {desviacion:.2f})")

# Leyenda y límites
plt.legend()
plt.ylim(0, max(p) + 0.05)
plt.xticks(x)

# Gráfica
plt.show()
# Out:
# La suma de las probabilidades es: 1.0
# E(X) = 8.50
# E(X²) = 215.00
# Varianza = 142.75
# Desviación Estándar = 11.95

# %%
#Función acumulada
F = np.cumsum(p)

# Resultados
for xi, fi in zip(x,F):
  print(f"F({xi}) = {fi:.2f}")

#Grafica
plt.step(x,F, where='post')
plt.title("Función de Distribución Acumulada Ganancia obtenida por boleto")
plt.xlabel("Ganancia obtenida por boleto")
plt.ylabel("Probabilidad acumulada")
plt.grid(True)
plt.ylim(0, 1.05)
plt.show()
# Out:
# F(0) = 0.50
# F(10) = 0.80
# F(20) = 0.95
# F(50) = 1.00

# %% [markdown]
# # Interpretación
# **¿Qué significa el valor esperado en este contexto?**
#
# El valor que esperamos en este contexto denota la cantidad de dinero que ganaremos por boleto, teniendo en éste caso un valor promedio de 8.5 por cada boleto comprado.
#
# **¿El juego es favorable para el jugador?**
# Al observar los datos podemos darnos cuenta que comprar un boleto para esta tómbola no es algo conveniente, ya que conseguir un premio bueno es algo bastante improbable, solo el 5% de los premios poseen un valor de 50, mientras un 15% tiene un precio de 20, y el otro 80% tiene un precio entre 0 y 10.
