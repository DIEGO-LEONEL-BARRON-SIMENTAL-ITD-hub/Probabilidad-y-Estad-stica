# %% [markdown]
# <a href="https://colab.research.google.com/github/DIEGO-LEONEL-BARRON-SIMENTAL-ITD-hub/Probabilidad-y-Estad-stica/blob/main/UNIDAD3/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadística
# ## Unidad 3
# ### Facilitador: José Gabriel Rodriguez Rivas
# ### Alumno: Diego Leonel Barrón Simental
# ### **Practica 1**

# %%
import matplotlib.pyplot as plt

# %%
x = [5,6,7,8,9,10]
p = [0.05,0.10,0.20,0.30,0.25,0.10]

# Verificar suma = 1
print("Suma de probabilidades:", sum(p))
#graficar distribución
plt.stem(x,p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Calificaión")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Suma de probabilidades: 1.0
