# %% [markdown]
# <a href="https://colab.research.google.com/github/DIEGO-LEONEL-BARRON-SIMENTAL-ITD-hub/Probabilidad-y-Estad-stica/blob/main/UNIDAD3/Practica_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadística
# ## Unidad 3
# ### Facilitador: José Gabriel Rodriguez Rivas
# ### Alumno: Diego Leonel Barrón Simental
# ### **Practica 8: Ejercicio 3**

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
# Variable aleatoria y sus probabilidades
x= np.array([0,1,2,3,4,5])
p= np.array([0.05,0.10,0.25,0.30,0.20,0.10])

print(f"La suma de las probabilidades es: {p.sum()}")

# Valor esperado
esperanza = np.sum(x*p)

#Esperanza al cuadrado
esperanza_cuadrado = np.sum(x**2 *p)

# Varianza y desviación estándar
varianza = esperanza_cuadrado - esperanza **2
desviacion = np.sqrt(varianza)

# Mostrar los resultados en consola
print(f"E(X) = {esperanza:.2f}")
print(f"E(X²) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviación Estándar = {desviacion:.2f}")

# Crear la gráfica 'stem' (tallos y hojas)
plt.stem(x, p, basefmt=" ", linefmt='b-',markerfmt='bo')
plt.title("Distribución de la probabilidad Discreta\ncon Media y Desviación Estándar")
plt.xlabel("Unidades vendidas por semana")
plt.ylabel("P(X)")
plt.grid(True, linestyle='--', alpha=0.6)

# Linea de la media
plt.axvline(x=esperanza, color='red', linestyle='--', label=f"Media (E(X)) = {esperanza:.2f}")

# Rango de ±1 desviación estándar
plt.axvspan(esperanza-desviacion, esperanza+desviacion, color='red',alpha=0.2,label=f"±1 Desv. Estándar (σ = {desviacion:.2f})")

# Leyenda y límites
plt.legend()
plt.ylim(0, max(p) + 0.05)
plt.xticks(x)

# Gráfica
plt.show()
# Out:
# La suma de las probabilidades es: 0.9999999999999999
# E(X) = 2.80
# E(X²) = 9.50
# Varianza = 1.66
# Desviación Estándar = 1.29

# %%
#Función acumulada
F = np.cumsum(p)

# Resultados
for xi, fi in zip(x,F):
  print(f"F({xi}) = {fi:.2f}")

#Grafica
plt.step(x,F, where='post')
plt.title("Función de Distribución Acumulada Unidades vendidas")
plt.xlabel("Unidades vendidas por semana")
plt.ylabel("Probabilidad acumulada")
plt.grid(True)
plt.ylim(0, 1.05)
plt.show()
# Out:
# F(0) = 0.05
# F(1) = 0.15
# F(2) = 0.40
# F(3) = 0.70
# F(4) = 0.90
# F(5) = 1.00

# %% [markdown]
# # Interpretación
# **¿Cuántas unidades se espera vender por semana?**
#
# Según lo observado en las gráficas lo más común es vender entre 2 a 4 unidades por semana, con un notable promedio de 2.8 unidades vendidas por semana.
#
# **¿La demanda es estable o muy variable?**
#
# La demanda presenta valores estables alrededor de 3 unidades vendidas por semana, con ocasionales elevaciones al vender 5 unidades por semana y disminuciones vendiendo 1 o ninguna unidad por semana.
