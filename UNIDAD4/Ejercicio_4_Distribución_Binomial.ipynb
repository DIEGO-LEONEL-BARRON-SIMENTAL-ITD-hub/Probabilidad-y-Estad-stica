# %% [markdown]
# <a href="https://colab.research.google.com/github/DIEGO-LEONEL-BARRON-SIMENTAL-ITD-hub/Probabilidad-y-Estad-stica/blob/main/UNIDAD4/Ejercicio_4_Distribuci%C3%B3n_Binomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Ejercicio 4**
# ###**Distribución Binomial**
#
# ###Facilitador: José Gabriel Rodriguez Rivas
# ###Alumno: Diego Leonel Barrón Simental

# %% [markdown]
# La probabilidad de éxito de una vacuna es de 0.83. Calcular la probabilidad de que una vez administrada a 16 pacientes NINGUNO sufra la enfermedad.

# %%
from scipy.stats import binom
# Parámetros de la distribución binomial
probabilidad_exito = 0.83
num_pacientes = 16
X = 16 # Número de exitos

# Calcular la probabilidad de que ningún paciente sufra la enfermedad
probabilidad_ninguno_enfermo = binom.pmf(X, num_pacientes, probabilidad_exito)
print("La probabilidad de que ningún paciente sufra la enfermedad es:", probabilidad_ninguno_enfermo)
# Out:
# La probabilidad de que ningún paciente sufra la enfermedad es: 0.0507282029895386

# %% [markdown]
# La probabilidad de éxito de una vacuna es de 0.83. Calcular la probabilidad de que una vez administrada a 16 pacientes TODOS sufra la enfermedad.

# %%
from scipy.stats import binom
# Parámetros de la distribución binomial
probabilidad_exito = 0.83
num_pacientes = 16
X = 0

# Calcular la probabilidad de que todos los pacientes sufran la enfermedad
probabilidad_todos_enfermos = binom.pmf(X, num_pacientes, probabilidad_exito)
print("La probabilidad de que todos los pacientes sufran la enfermedad es:", probabilidad_todos_enfermos)
# Out:
# La probabilidad de que todos los pacientes sufran la enfermedad es: 4.866119187566701e-13
