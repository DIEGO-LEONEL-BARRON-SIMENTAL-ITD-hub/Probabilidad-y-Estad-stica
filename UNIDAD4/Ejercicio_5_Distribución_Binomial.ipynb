# %% [markdown]
# <a href="https://colab.research.google.com/github/DIEGO-LEONEL-BARRON-SIMENTAL-ITD-hub/Probabilidad-y-Estad-stica/blob/main/UNIDAD4/Ejercicio_5_Distribuci%C3%B3n_Binomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Ejercicio 5**
# ##Distribución Binomial Ejercicio 2
#
# ###Facilitador: José Gabriel Rodriguez Rivas
# ###Alumno: Diego Leonel Barrón Simental

# %% [markdown]
# Para una variable aleatoria binomial con n = 10 y una probabilidad de 0.10
# Encontrar la probabilidad de la variable aleatoria x = 2.

# %%
from scipy.stats import binom
# Parámetros de la distribución binomial
n = 10
p = 0.10
x = 2

# Calcular la probabilidad de la variable aleatoria X = 2
probabilidad_x_2 = binom.pmf(x, n, p)
print("La probabilidad de que la variable aleatoria X sea igual a 2 es:", probabilidad_x_2)
# Out:
# La probabilidad de que la variable aleatoria X sea igual a 2 es: 0.19371024450000007
