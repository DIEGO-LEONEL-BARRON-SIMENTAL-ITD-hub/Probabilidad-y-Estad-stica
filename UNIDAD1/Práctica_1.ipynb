# %% [markdown]
# <a href="https://colab.research.google.com/github/DIEGO-LEONEL-BARRON-SIMENTAL-ITD-hub/Probabilidad-y-Estad-stica/blob/main/UNIDAD1/Pr%C3%A1ctica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadística
# ## Unidad 1
# ### Facilitador: José Gabriel Rodriguez Rivas
# ### Alumno: Diego Leonel Barrón Simental
# ### **Programa 1: Estadística básica e Histograma**

# %%
from statistics import *

# %%
# Lista de calificaciónes del grupo a de probabilidad y estadística
grupoa=[70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
# La función type nos devuelve el tipo de dato de la variable
type(grupoa)
# Out:
# list

# %%
# Sacar la media de las calificaciones con una fórmula
promedio = sum(grupoa)/len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
#Utilizar la función mean que está en la librería en la librería statistics para sacar el promedio
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333
