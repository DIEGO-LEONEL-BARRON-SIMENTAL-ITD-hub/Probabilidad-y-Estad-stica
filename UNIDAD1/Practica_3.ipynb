# %% [markdown]
# <a href="https://colab.research.google.com/github/DIEGO-LEONEL-BARRON-SIMENTAL-ITD-hub/Probabilidad-y-Estad-stica/blob/main/UNIDAD1/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadística
# ## Unidad 1
# ### Facilitador: José Gabriel Rodriguez Rivas
# ### Alumno: Diego Leonel Barrón Simental
# ### **Practica 3: Tabla de frecuencias**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
#creamos una lista vacía que representa la edad de 100 personas
edades = []

for i in range (100):
  numero_aleatorio=random.randint(18,70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [28, 39, 24, 57, 40, 32, 63, 56, 40, 45, 34, 52, 50, 24, 70, 53, 66, 39, 53, 22, 27, 48, 52, 32, 49, 40, 27, 20, 46, 42, 55, 69, 51, 22, 18, 63, 53, 52, 44, 57, 52, 50, 67, 64, 49, 37, 47, 22, 66, 35, 54, 43, 68, 66, 31, 28, 21, 32, 60, 35, 44, 38, 68, 60, 40, 45, 56, 35, 19, 56, 36, 34, 36, 23, 47, 51, 42, 24, 24, 43, 55, 19, 66, 29, 68, 48, 50, 23, 30, 60, 40, 62, 59, 29, 39, 35, 34, 23, 37, 28]

# %%
import pandas as pd

# %%
#Crear un DataFrame de pandas con los números aleatorios
df= pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    28
# 1    39
# 2    24
# 3    57
# 4    40

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias= df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

#Imprimir la tabla de frcuencias
print("Tabla de Distribución de Frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 37    18           1
# 30    19           2
# 34    20           1
# 39    21           1
# 10    22           3
# 14    23           3
# 1     24           4
# 20    27           2
# 13    28           3
# 18    29           2
# 43    30           1
# 41    31           1
# 12    32           3
# 9     34           3
# 4     35           4
# 24    36           2
# 22    37           2
# 42    38           1
# 5     39           3
# 0     40           5
# 27    42           2
# 25    43           2
# 23    44           2
# 19    45           2
# 35    46           1
# 31    47           2
# 21    48           2
# 26    49           2
# 8     50           3
# 28    51           2
# 2     52           4
# 6     53           3
# 40    54           1
# 29    55           2
# 7     56           3
# 17    57           2
# 45    59           1
# 15    60           3
# 44    62           1
# 16    63           2
# 38    64           1
# 3     66           4
# 33    67           1
# 11    68           3
# 36    69           1
# 32    70           1

# %%
tabla_frecuencias['Frec Relativa']= tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 37    18           1           0.01
# 30    19           2           0.02
# 34    20           1           0.01
# 39    21           1           0.01
# 10    22           3           0.03
# 14    23           3           0.03
# 1     24           4           0.04
# 20    27           2           0.02
# 13    28           3           0.03
# 18    29           2           0.02
# 43    30           1           0.01
# 41    31           1           0.01
# 12    32           3           0.03
# 9     34           3           0.03
# 4     35           4           0.04
# 24    36           2           0.02
# 22    37           2           0.02
# 42    38           1           0.01
# 5     39           3           0.03
# 0     40           5           0.05
# 27    42           2           0.02
# 25    43           2           0.02
# 23    44           2           0.02
# 19    45           2           0.02
# 35    46           1           0.01
# 31    47           2           0.02
# 21    48           2           0.02
# 26    49           2           0.02
# 8     50           3           0.03
# 28    51           2           0.02
# 2     52           4           0.04
# 6     53           3           0.03
# 40    54           1           0.01
# 29    55           2           0.02
# 7     56           3           0.03
# 17    57           2           0.02
# 45    59           1           0.01
# 15    60           3           0.03
# 44    62           1           0.01
# 16    63           2           0.02
# 38    64           1           0.01
# 3     66           4           0.04
# 33    67           1           0.01
# 11    68           3           0.03
# 36    69           1           0.01
# 32    70           1           0.01

# %%
tabla_frecuencias['Frec Porcentual']= tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 37    18           1           0.01              1.0
# 30    19           2           0.02              2.0
# 34    20           1           0.01              1.0
# 39    21           1           0.01              1.0
# 10    22           3           0.03              3.0
# 14    23           3           0.03              3.0
# 1     24           4           0.04              4.0
# 20    27           2           0.02              2.0
# 13    28           3           0.03              3.0
# 18    29           2           0.02              2.0
# 43    30           1           0.01              1.0
# 41    31           1           0.01              1.0
# 12    32           3           0.03              3.0
# 9     34           3           0.03              3.0
# 4     35           4           0.04              4.0
# 24    36           2           0.02              2.0
# 22    37           2           0.02              2.0
# 42    38           1           0.01              1.0
# 5     39           3           0.03              3.0
# 0     40           5           0.05              5.0
# 27    42           2           0.02              2.0
# 25    43           2           0.02              2.0
# 23    44           2           0.02              2.0
# 19    45           2           0.02              2.0
# 35    46           1           0.01              1.0
# 31    47           2           0.02              2.0
# 21    48           2           0.02              2.0
# 26    49           2           0.02              2.0
# 8     50           3           0.03              3.0
# 28    51           2           0.02              2.0
# 2     52           4           0.04              4.0
# 6     53           3           0.03              3.0
# 40    54           1           0.01              1.0
# 29    55           2           0.02              2.0
# 7     56           3           0.03              3.0
# 17    57           2           0.02              2.0
# 45    59           1           0.01              1.0
# 15    60           3           0.03              3.0
# 44    62           1           0.01              1.0
# 16    63           2           0.02              2.0
# 38    64           1           0.01              1.0
# 3     66           4           0.04              4.0
# 33    67           1           0.01              1.0
# 11    68           3           0.03              3.0
# 36    69           1           0.01              1.0
# 32    70           1           0.01              1.0

# %%
tabla_frecuencias['Frec acumulada']= tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec acumulada
# 37    18           1           0.01              1.0               1
# 30    19           2           0.02              2.0               3
# 34    20           1           0.01              1.0               4
# 39    21           1           0.01              1.0               5
# 10    22           3           0.03              3.0               8
# 14    23           3           0.03              3.0              11
# 1     24           4           0.04              4.0              15
# 20    27           2           0.02              2.0              17
# 13    28           3           0.03              3.0              20
# 18    29           2           0.02              2.0              22
# 43    30           1           0.01              1.0              23
# 41    31           1           0.01              1.0              24
# 12    32           3           0.03              3.0              27
# 9     34           3           0.03              3.0              30
# 4     35           4           0.04              4.0              34
# 24    36           2           0.02              2.0              36
# 22    37           2           0.02              2.0              38
# 42    38           1           0.01              1.0              39
# 5     39           3           0.03              3.0              42
# 0     40           5           0.05              5.0              47
# 27    42           2           0.02              2.0              49
# 25    43           2           0.02              2.0              51
# 23    44           2           0.02              2.0              53
# 19    45           2           0.02              2.0              55
# 35    46           1           0.01              1.0              56
# 31    47           2           0.02              2.0              58
# 21    48           2           0.02              2.0              60
# 26    49           2           0.02              2.0              62
# 8     50           3           0.03              3.0              65
# 28    51           2           0.02              2.0              67
# 2     52           4           0.04              4.0              71
# 6     53           3           0.03              3.0              74
# 40    54           1           0.01              1.0              75
# 29    55           2           0.02              2.0              77
# 7     56           3           0.03              3.0              80
# 17    57           2           0.02              2.0              82
# 45    59           1           0.01              1.0              83
# 15    60           3           0.03              3.0              86
# 44    62           1           0.01              1.0              87
# 16    63           2           0.02              2.0              89
# 38    64           1           0.01              1.0              90
# 3     66           4           0.04              4.0              94
# 33    67           1           0.01              1.0              95
# 11    68           3           0.03              3.0              98
# 36    69           1           0.01              1.0              99
# 32    70           1           0.01              1.0             100

# %% [markdown]
# ##Regla de Sturgres

# %%
import math

# %%
print(edades)
# Out:
# [28, 39, 24, 57, 40, 32, 63, 56, 40, 45, 34, 52, 50, 24, 70, 53, 66, 39, 53, 22, 27, 48, 52, 32, 49, 40, 27, 20, 46, 42, 55, 69, 51, 22, 18, 63, 53, 52, 44, 57, 52, 50, 67, 64, 49, 37, 47, 22, 66, 35, 54, 43, 68, 66, 31, 28, 21, 32, 60, 35, 44, 38, 68, 60, 40, 45, 56, 35, 19, 56, 36, 34, 36, 23, 47, 51, 42, 24, 24, 43, 55, 19, 66, 29, 68, 48, 50, 23, 30, 60, 40, 62, 59, 29, 39, 35, 34, 23, 37, 28]

# %%
df= pd.DataFrame({'Edad':edades})
df
# Out:
#     Edad
# 0     28
# 1     39
# 2     24
# 3     57
# 4     40
# ..   ...
# 95    35
# 96    34
# 97    23
# 98    37
# 99    28
#
# [100 rows x 1 columns]

# %%
#Calcular el número de intervalos utilizando la ley de sturges
n=len(edades)
K=int(1+math.log2(n))
print("Valor de n = ",n,"\nNumero de intervalos = ", K)
# Out:
# Valor de n =  100
# Numero de intervalos =  7

# %%
# Crear la tabla de frecuencia

tabla_frecuencia = pd.cut(df['Edad'], bins = K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase','Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (32.857, 40.286]    20
# 1  (47.714, 55.143]    19
# 2  (17.947, 25.429]    15
# 3    (62.571, 70.0]    13
# 4  (25.429, 32.857]    12
# 5  (40.286, 47.714]    11
# 6  (55.143, 62.571]    10

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 2  (17.947, 25.429]    15
# 4  (25.429, 32.857]    12
# 0  (32.857, 40.286]    20
# 5  (40.286, 47.714]    11
# 1  (47.714, 55.143]    19
# 6  (55.143, 62.571]    10
# 3    (62.571, 70.0]    13

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec']/ n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()
# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 2  (17.947, 25.429]    15      0.15       15.0       15         0.15
# 4  (25.429, 32.857]    12      0.12       12.0       27         0.27
# 0  (32.857, 40.286]    20      0.20       20.0       47         0.47
# 5  (40.286, 47.714]    11      0.11       11.0       58         0.58
# 1  (47.714, 55.143]    19      0.19       19.0       77         0.77
# 6  (55.143, 62.571]    10      0.10       10.0       87         0.87
# 3    (62.571, 70.0]    13      0.13       13.0      100         1.00
#
#    Frec Porc Ac
# 2          15.0
# 4          27.0
# 0          47.0
# 5          58.0
# 1          77.0
# 6          87.0
# 3         100.0

# %%
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
